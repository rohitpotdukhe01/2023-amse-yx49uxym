# %% [markdown]
# # Data Exploration
#
# In this notebook describe your data exploration steps.

# %% [markdown]
# ## Install dependencies

# %%
# %pip install pandas
# %pip install 'SQLAlchemy==1.4.46'
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load data

# %%
import pandas as pd

df_bike_2022 = pd.read_sql_table('Bicycle_Traffic_Data_Cologne_2022', 'sqlite:///data/AMSE_database.sqlite')
df_bike_2021 = pd.read_sql_table('Bicycle_Traffic_Data_Cologne_2021', 'sqlite:///data/AMSE_database.sqlite')
df_bike_2020 = pd.read_sql_table('Bicycle_Traffic_Data_Cologne_2020', 'sqlite:///data/AMSE_database.sqlite')

# %% [markdown]
# ### Look at the first rows

# %%
df_bike_2022.head()
# Out:
#      Month  Deutzer Brücke  Hohenzollernbrücke  Neumarkt  Zülpicher Straße
# 0   Januar          88.423              52.307    84.708           104.967  \
# 1  Februar          83.211              48.554    78.712            91.977
# 2     März         146.113              79.597   126.461           144.872
# 3    April         138.641              67.561   117.343           144.233
# 4      Mai         192.947              94.384   165.976           189.672
#
#    Bonner Straße  Venloer Straße  Vorgebirgswall  Universitäts-straße
# 0         63.658         124.574          68.031              110.382  \
# 1         58.148         114.010          67.684              100.106
# 2         82.610         170.757          99.689              143.526
# 3         75.400         159.079          88.120              146.349
# 4         97.080         207.376         116.181              201.871
#
#    A.-Schütte-Allee  Vorgebirgspark  A.-Silbermann-Weg  Stadtwald
# ...

# %%
df_bike_2020.head()
# Out:
#      Month  Deutzer Brücke  Hohenzollernbrücke  Neumarkt  Zülpicher Straße
# 0   Januar          94.562              58.212    99.159           114.081  \
# 1  Februar          69.823              45.148    74.954           106.795
# 2     März          92.932              56.779    81.978           110.074
# 3    April         140.106              75.557   101.160           119.539
# 4      Mai         177.128              88.478   146.901           163.252
#
#    Bonner Straße  Venloer Straße  Vorgebirgswall  Universitäts-straße
# 0         81.756         142.100          77.318                0.000  \
# 1         65.346         111.385          61.262                0.000
# 2         71.334         123.461          68.409                0.000
# 3         84.150         149.758          86.527              112.245
# 4        107.677         198.192         107.696              147.928
#
#    A.-Schütte-Allee  Vorgebirgspark  A.-Silbermann-Weg  Stadtwald
# ...

# %%
df_bike_2021.head()
# Out:
#      Month  Deutzer Brücke  Hohenzollernbrücke  Neumarkt  Zülpicher Straße
# 0   Januar          62.891              41.003    52.081            67.903  \
# 1  Februar          84.472              48.935    63.627            80.690
# 2     März         114.846              65.838    94.799           107.955
# 3    April         110.865              63.283    80.753           106.172
# 4      Mai         110.115              65.275    85.309           116.561
#
#    Bonner Straße  Venloer Straße  Vorgebirgswall  Universitäts-straße
# 0         55.270          93.471          52.486               81.065  \
# 1         59.499         107.032          62.629               90.069
# 2         84.759         147.321          83.349              118.573
# 3         70.522         145.596          80.127              110.035
# 4         59.282         158.116          84.925              116.043
#
#    A.-Schütte-Allee  Vorgebirgspark  A.-Silbermann-Weg  Stadtwald
# ...

# %% [markdown]
# ### Data exploration
# Print some basic information about the data. Your data exploration would continue here.

# %% [markdown]
# #### Basic Data Exploration steps

# %%
df_bike_2020.info()
df_bike_2021.info()
df_bike_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                12 non-null     object
#  1   Deutzer Brücke       12 non-null     float64
#  2   Hohenzollernbrücke   12 non-null     float64
#  3   Neumarkt             12 non-null     float64
#  4   Zülpicher Straße     12 non-null     float64
#  5   Bonner Straße        12 non-null     float64
#  6   Venloer Straße       12 non-null     float64
#  7   Vorgebirgswall       12 non-null     float64
#  8   Universitäts-straße  12 non-null     float64
#  9   A.-Schütte-Allee     12 non-null     float64
#  10  Vorgebirgspark       12 non-null     float64
#  11  A.-Silbermann-Weg    12 non-null     float64
#  12  Stadtwald            12 non-null     float64
#  13  Niederländer Ufer    12 non-null     float64
# dtypes: float64(13), object(1)
# memory usage: 1.4+ KB
# ...

# %%
df_bike_2020.describe()
# Out:
#        Deutzer Brücke  Hohenzollernbrücke    Neumarkt  Zülpicher Straße
# count       12.000000           12.000000   12.000000         12.000000  \
# mean       137.146500           74.020667  123.173750        141.033333
# std         45.974786           18.928061   38.079768         34.975365
# min         69.823000           45.148000   72.296000         77.940000
# 25%         94.154500           57.853750   94.863750        113.079250
# 50%        137.960000           74.115500  117.962500        144.329500
# 75%        180.211500           89.114000  163.399750        172.581750
# max        191.427000           99.264000  169.083000        186.013000
#
#        Bonner Straße  Venloer Straße  Vorgebirgswall  Universitäts-straße
# count      12.000000       12.000000       12.000000            12.000000  \
# mean       95.962250      168.371667       91.365167            99.050417
# std        22.519761       42.362948       22.907098            65.683006
# ...

# %%
df_bike_2021.describe()
# Out:
#        Deutzer Brücke  Hohenzollernbrücke    Neumarkt  Zülpicher Straße
# count       12.000000           12.000000   12.000000         12.000000  \
# mean       123.285917           69.101000  107.523833        125.156750
# std         33.670289           18.022413   34.990397         34.762933
# min         62.891000           41.003000   52.081000         67.903000
# 25%        108.382500           59.698750   84.170000        105.669250
# 50%        116.764000           65.556500  100.048000        119.314500
# 75%        144.544250           80.245750  136.592000        155.268250
# max        183.553000           98.337000  157.548000        178.758000
#
#        Bonner Straße  Venloer Straße  Vorgebirgswall  Universitäts-straße
# count      12.000000       12.000000       12.000000            12.000000  \
# mean       74.001833      161.976000       86.413667           128.251417
# std        11.965587       40.222788       20.971933            29.545125
# ...

# %%
df_bike_2022.describe()
# Out:
#        Deutzer Brücke  Hohenzollernbrücke    Neumarkt  Zülpicher Straße
# count       12.000000           12.000000   12.000000         12.000000  \
# mean       142.528833           73.095250  126.157417        148.239500
# std         39.408101           18.167063   28.985741         31.333164
# min         83.211000           43.723000   78.712000         91.977000
# 25%        123.869500           63.747500  110.544000        134.544500
# 50%        149.497500           76.995000  131.586000        159.260000
# 75%        162.406750           80.611500  145.178250        169.839750
# max        199.040000          104.883000  165.976000        189.672000
#
#        Bonner Straße  Venloer Straße  Vorgebirgswall  Universitäts-straße
# count      12.000000       12.000000       12.000000            12.000000  \
# mean       79.392000      167.610167       92.718667           133.047583
# std        13.336273       31.984266       19.268137            36.846167
# ...

# %% [markdown]
# ### Street with most number of bikers for year 2022

# %%
#Street with most number of bikers for year 2020

import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['Deutzer Brücke'].values != 0, df_bike_2020['Deutzer Brücke'], np.nan), label='Deutzer Brücke')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['Hohenzollernbrücke'].values != 0, df_bike_2020['Hohenzollernbrücke'], np.nan), label='Hohenzollernbrücke')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['Zülpicher Straße'].values != 0, df_bike_2020['Zülpicher Straße'], np.nan), label='Zülpicher Straße')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['Bonner Straße'].values != 0, df_bike_2020['Bonner Straße'], np.nan), label='Bonner Straße')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['Venloer Straße'].values != 0, df_bike_2020['Venloer Straße'], np.nan), label='Venloer Straße')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['Vorgebirgswall'].values != 0, df_bike_2020['Vorgebirgswall'], np.nan), label='Vorgebirgswall')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['Universitäts-straße'].values != 0, df_bike_2020['Universitäts-straße'], np.nan), label='Universitäts-straße')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['A.-Schütte-Allee'].values != 0, df_bike_2020['A.-Schütte-Allee'], np.nan), label='A.-Schütte-Allee')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['Vorgebirgspark'].values != 0, df_bike_2020['Vorgebirgspark'], np.nan), label='Vorgebirgspark')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['A.-Silbermann-Weg'].values != 0, df_bike_2020['A.-Silbermann-Weg'], np.nan), label='A.-Silbermann-Weg')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['Stadtwald'].values != 0, df_bike_2020['Stadtwald'], np.nan), label='Stadtwald')
plt.plot(df_bike_2020['Month'], np.where(df_bike_2020['Niederländer Ufer'].values != 0, df_bike_2020['Niederländer Ufer'], np.nan), label='Niederländer Ufer')
plt.xlabel('Month')
plt.ylabel('Bicycle Traffic')
plt.title('Bicycle Traffic Over Time (2020)')
legend = plt.legend(fontsize=5)
plt.xticks(rotation=45)
plt.show()

# %%
#Street with most number of bikers for year 2021

import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Deutzer Brücke'].values != 0, df_bike_2021['Deutzer Brücke'], np.nan), label='Deutzer Brücke')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Hohenzollernbrücke'].values != 0, df_bike_2021['Hohenzollernbrücke'], np.nan), label='Hohenzollernbrücke')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Zülpicher Straße'].values != 0, df_bike_2021['Zülpicher Straße'], np.nan), label='Zülpicher Straße')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Bonner Straße'].values != 0, df_bike_2021['Bonner Straße'], np.nan), label='Bonner Straße')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Venloer Straße'].values != 0, df_bike_2021['Venloer Straße'], np.nan), label='Venloer Straße')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Vorgebirgswall'].values != 0, df_bike_2021['Vorgebirgswall'], np.nan), label='Vorgebirgswall')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Universitäts-straße'].values != 0, df_bike_2021['Universitäts-straße'], np.nan), label='Universitäts-straße')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['A.-Schütte-Allee'].values != 0, df_bike_2021['A.-Schütte-Allee'], np.nan), label='A.-Schütte-Allee')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Vorgebirgspark'].values != 0, df_bike_2021['Vorgebirgspark'], np.nan), label='Vorgebirgspark')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['A.-Silbermann-Weg'].values != 0, df_bike_2021['A.-Silbermann-Weg'], np.nan), label='A.-Silbermann-Weg')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Stadtwald'].values != 0, df_bike_2021['Stadtwald'], np.nan), label='Stadtwald')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Niederländer Ufer'].values != 0, df_bike_2021['Niederländer Ufer'], np.nan), label='Niederländer Ufer')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Rodenkirchener Brücke'].values != 0, df_bike_2021['Rodenkirchener Brücke'], np.nan), label='Rodenkirchener Brücke')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Severinsbrücke'].values != 0, df_bike_2021['Severinsbrücke'], np.nan), label='Severinsbrücke')
plt.plot(df_bike_2021['Month'], np.where(df_bike_2021['Neusser Straße'].values != 0, df_bike_2021['Neusser Straße'], np.nan), label='Neusser Straße')
plt.xlabel('Month')
plt.ylabel('Bicycle Traffic')
plt.title('Bicycle Traffic Over Time (2020)')
legend = plt.legend(fontsize=5)
plt.xticks(rotation=45)
plt.show()

# %%
#Street with most number of bikers for year 2022

import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Deutzer Brücke'].values != 0, df_bike_2022['Deutzer Brücke'], np.nan), label='Deutzer Brücke')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Hohenzollernbrücke'].values != 0, df_bike_2022['Hohenzollernbrücke'], np.nan), label='Hohenzollernbrücke')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Neumarkt'].values != 0, df_bike_2022['Neumarkt'], np.nan), label='Neumarkt')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Zülpicher Straße'].values != 0, df_bike_2022['Zülpicher Straße'], np.nan), label='Zülpicher Straße')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Bonner Straße'].values != 0, df_bike_2022['Bonner Straße'], np.nan), label='Bonner Straße')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Venloer Straße'].values != 0, df_bike_2022['Venloer Straße'], np.nan), label='Venloer Straße')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Vorgebirgswall'].values != 0, df_bike_2022['Vorgebirgswall'], np.nan), label='Vorgebirgswall')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Universitäts-straße'].values != 0, df_bike_2022['Universitäts-straße'], np.nan), label='Universitäts-straße')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['A.-Schütte-Allee'].values != 0, df_bike_2022['A.-Schütte-Allee'], np.nan), label='A.-Schütte-Allee')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Vorgebirgspark'].values != 0, df_bike_2022['Vorgebirgspark'], np.nan), label='Vorgebirgspark')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['A.-Silbermann-Weg'].values != 0, df_bike_2022['A.-Silbermann-Weg'], np.nan), label='A.-Silbermann-Weg')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Stadtwald'].values != 0, df_bike_2022['Stadtwald'], np.nan), label='Stadtwald')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Niederländer Ufer'].values != 0, df_bike_2022['Niederländer Ufer'], np.nan), label='Niederländer Ufer')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Rodenkirchener Brücke'].values != 0, df_bike_2022['Rodenkirchener Brücke'], np.nan), label='Rodenkirchener Brücke')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Severinsbrücke'].values != 0, df_bike_2022['Severinsbrücke'], np.nan), label='Severinsbrücke')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Hohe Pforte'].values != 0, df_bike_2022['Hohe Pforte'], np.nan), label='Hohe Pforte')
plt.plot(df_bike_2022['Month'], np.where(df_bike_2022['Neusser Straße'].values != 0, df_bike_2022['Neusser Straße'], np.nan), label='Neusser Straße')
plt.xlabel('Month')
plt.ylabel('Bicycle Traffic')
plt.title('Bicycle Traffic Over Time (2020)')
legend = plt.legend(fontsize=5)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Street with highest and lowest and highest number of bike riders for different years

# %%
bike_traffic = df_bike_2020.drop('Month', axis=1).sum()

# Find the street with the highest total bicycle traffic
street_with_most_bikers = bike_traffic.idxmax()
street_with_least_bikers = bike_traffic.idxmin()


# Print the street with the most number of bikers
print("Street with the most number of bikers in 2020:", street_with_most_bikers)
# Print the street with the least traveled
print("Street with the least traveled in 2020:", street_with_least_bikers)
# Out:
# Street with the most number of bikers in 2020: Venloer Straße
# Street with the least traveled in 2020: Vorgebirgspark

# %%
bike_traffic = df_bike_2021.drop('Month', axis=1).sum()

# Find the street with the highest total bicycle traffic
street_with_most_bikers = bike_traffic.idxmax()
street_with_least_bikers = bike_traffic.idxmin()


# Print the street with the most number of bikers
print("Street with the most number of bikers in 2021:", street_with_most_bikers)
# Print the street with the least traveled
print("Street with the least traveled in 2021:", street_with_least_bikers)
# Out:
# Street with the most number of bikers in 2021: Venloer Straße
# Street with the least traveled in 2021: Vorgebirgspark

# %%
bike_traffic = df_bike_2022.drop('Month', axis=1).sum()

# Find the street with the highest total bicycle traffic
street_with_most_bikers = bike_traffic.idxmax()
street_with_least_bikers = bike_traffic.idxmin()


# Print the street with the most number of bikers
print("Street with the most number of bikers in 2022:", street_with_most_bikers)
# Print the street with the least traveled
print("Street with the least traveled in 2022:", street_with_least_bikers)
# Out:
# Street with the most number of bikers in 2022: Venloer Straße
# Street with the least traveled in 2022: Vorgebirgspark

# %% [markdown]
# ### Bar plot of Total Bicycle Traffic per month for year 2020, 2021, 2022, for street Venloer Straße

# %%
#Bar plot of Total Bicycle Traffic per month for year 2020, 2021, 2022, for street Venloer Straße
import matplotlib.pyplot as plt

monthly_traffic_2020 = df_bike_2020.groupby('Month').sum()
monthly_traffic_2021 = df_bike_2021.groupby('Month').sum()
monthly_traffic_2022 = df_bike_2022.groupby('Month').sum()

plt.figure(figsize=(10, 6))
plt.bar(monthly_traffic_2020.index, monthly_traffic_2020['Venloer Straße'], label='Venloer Straße 2020')
plt.bar(monthly_traffic_2021.index, monthly_traffic_2021['Venloer Straße'], label='Venloer Straße 2021')
plt.bar(monthly_traffic_2022.index, monthly_traffic_2022['Venloer Straße'], label='Venloer Straße 2022')
plt.xlabel('Month')
plt.ylabel('Total Bicycle Traffic')
plt.title('Total Bicycle Traffic per Month')
plt.xticks(rotation=45)
legend = plt.legend(fontsize=5)
plt.show()
